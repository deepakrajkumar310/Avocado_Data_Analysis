# %% [markdown]
# ## Data Observation

# %% [markdown]
# It represents weekly retail scan data for National retail volume (units) and price of avocados.

# %% [markdown]
# ## Loading the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading Data

# %%
avocado_df = pd.read_csv("avocado.csv")

# %%
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado_df.drop(columns=["Unnamed: 0",],inplace=True,axis=1)

# %%
avocado_df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado_df.tail()
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# ...

# %%
avocado_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
avocado_df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
avocado_df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
avocado_df.describe(include="O")
# Out:
#               Date          type  region
# count        18249         18249   18249
# unique         169             2      54
# top     2015-12-27  conventional  Albany
# freq           108          9126     338

# %% [markdown]
# ### Conclusion:
#
# It is observed that there are no null values in the data from info() function.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Exploring *"AveragePrice"* column

# %%
avocado_df["AveragePrice"].mean()
# Out:
# 1.405978409775878

# %%
avocado_df["AveragePrice"].min()
# Out:
# 0.44

# %%
avocado_df["AveragePrice"].max()
# Out:
# 3.25

# %%
avocado_df["AveragePrice"].median()
# Out:
# 1.37

# %%
avocado_df["AveragePrice"].std()
# Out:
# 0.40267655549555004

# %%
avocado_df["AveragePrice"].var()
# Out:
# 0.16214840834576077

# %%
avocado_df["AveragePrice"].skew()
# Out:
# 0.5803027378878419

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["AveragePrice"],color="aqua")

plt.title("Histogram plot of AveragePrice",y=1.02)
plt.xlabel("AveragePrice")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["AveragePrice"],kind="kde",color="green")

plt.title("Density plot of AveragePrice",y=1.02)
plt.xlabel("AveragePrice")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["AveragePrice"].quantile(0.10),avocado_df["AveragePrice"].quantile(0.25),avocado_df["AveragePrice"].quantile(0.50),avocado_df["AveragePrice"].quantile(0.75),avocado_df["AveragePrice"].quantile(0.90)
# Out:
# (0.93, 1.1, 1.37, 1.66, 1.93)

# %%
sns.boxplot(avocado_df["AveragePrice"],orient="h",color="plum")

plt.title("Box plot for AveragePrice",y=1.02)
plt.xlabel("AveragePrice")
plt.show()

# %%
sns.violinplot(avocado_df["AveragePrice"],orient="h",color="aquamarine")

plt.title("Violin plot for AveragePrice",y=1.02)
plt.xlabel("AveragePrice")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **AveragePrice** has an asymmetrical distribution i.e., it is skewed with a skewness value of 0.58
#
# * The Density curve of *AveragePrice* column is centered along mean 1.406 with standard deviation of 0.403.
# * The range of the values is from 0.44 to 3.25.
# * Most of the values are in the range of 1 to 2.
# * 10% of times the AveragePrice is 0.93 and below.
# * 25% of times the AveragePrice is 1.1 and below.
# * 50% of times the AveragePrice is 1.37 and below.
# * 75% of times the AveragePrice is 1.66 and below.
# * 90% of times the AveragePrice is 1.93 and below.
# * *AveragePrice* column is having outliers (i.e., extreme values) towards higher side.
#
# **AveragePrice** column can be further explored with other columns

# %% [markdown]
# ### Exploring *"Total Volume"* column

# %%
avocado_df["Total Volume"].mean()
# Out:
# 850644.0130089321

# %%
avocado_df["Total Volume"].min()
# Out:
# 84.56

# %%
avocado_df["Total Volume"].max()
# Out:
# 62505646.52

# %%
avocado_df["Total Volume"].median()
# Out:
# 107376.76

# %%
avocado_df["Total Volume"].std()
# Out:
# 3453545.3553994815

# %%
avocado_df["Total Volume"].var()
# Out:
# 11926975521801.33

# %%
avocado_df["Total Volume"].skew()
# Out:
# 9.00768747885452

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["Total Volume"],color="purple")

plt.title("Histogram plot of Total Volume",y=1.02)
plt.xlabel("Total Volume")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["Total Volume"],kind="kde",color="indigo")

plt.title("Density plot of Total Volume",y=1.02)
plt.xlabel("Total Volume")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["Total Volume"].quantile(0.10),avocado_df["Total Volume"].quantile(0.25),avocado_df["Total Volume"].quantile(0.50),avocado_df["Total Volume"].quantile(0.75),avocado_df["Total Volume"].quantile(0.90)
# Out:
# (3896.7680000000005, 10838.58, 107376.76, 432962.29, 1387045.7600000002)

# %%
sns.boxplot(avocado_df["Total Volume"],orient="h")

plt.title("Box plot for Total Volume",y=1.02)
plt.xlabel("Total Volume")
plt.show()

# %%
sns.violinplot(avocado_df["Total Volume"],orient="h",color="beige")

plt.title("Violin plot for Total Volume",y=1.02)
plt.xlabel("Total Volume")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **Total Volume** has an asymmetrical distribution i.e., it is skewed with a skewness value of 9.007
#
# * The Density curve of *Total Volume* column is centered along mean 850644.013 with standard deviation of 3453545.355.
# * The range of the values is from 84.56 to 62505646.52.
# * Most of the values are in the range of 100 to 1000000.
# * 10% of times the total sales volume of avocados is 3896.768 and below.
# * 25% of times the total sales volume of avocados is 10838.58 and below.
# * 50% of times the total sales volume of avocados is 107376.76 and below.
# * 75% of times the total sales volume of avocados is 432962.29 and below.
# * 90% of times the total sales volume of avocados is 1387045.76 and below.
# * *Total Volume* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"4046"* column

# %%
avocado_df["4046"].mean()
# Out:
# 293008.4245306592

# %%
avocado_df["4046"].min()
# Out:
# 0.0

# %%
avocado_df["4046"].max()
# Out:
# 22743616.17

# %%
avocado_df["4046"].median()
# Out:
# 8645.3

# %%
avocado_df["4046"].std()
# Out:
# 1264989.081762766

# %%
avocado_df["4046"].var()
# Out:
# 1600197376979.0056

# %%
avocado_df["4046"].skew()
# Out:
# 8.648219757025226

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["4046"],color="salmon")

plt.title("Histogram plot of 4046",y=1.02)
plt.xlabel("4046")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["4046"],kind="kde",color="red")

plt.title("Density plot of 4046",y=1.02)
plt.xlabel("4046")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["4046"].quantile(0.10),avocado_df["4046"].quantile(0.25),avocado_df["4046"].quantile(0.50),avocado_df["4046"].quantile(0.75),avocado_df["4046"].quantile(0.90)
# Out:
# (94.27600000000002, 854.07, 8645.3, 111020.2, 538385.184)

# %%
sns.boxplot(avocado_df["4046"],orient="h")

plt.title("Box plot for 4046",y=1.02)
plt.xlabel("4046")
plt.show()

# %%
sns.violinplot(avocado_df["4046"],orient="h",color="sienna")

plt.title("Violin plot for 4046",y=1.02)
plt.xlabel("4046")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **4046** has an asymmetrical distribution i.e., it is skewed with a skewness value of 8.648
#
# * The Density curve of *4046* column is centered along mean 293008.424 with standard deviation of 1264989.081.
# * The range of the values is from 0 to 22743616.17.
# * Most of the values are in the range of 100 to 1000000.
# * 10% of times the total sales volume of Small/Medium Hass Avocados is 94.276 and below.
# * 25% of times the total sales volume of Small/Medium Hass Avocados is 854.07 and below.
# * 50% of times the total sales volume of Small/Medium Hass Avocados is 8645.3 and below.
# * 75% of times the total sales volume of Small/Medium Hass Avocados is 111020.2 and below.
# * 90% of times the total sales volume of Small/Medium Hass Avocados is 538385.184 and below.
# * *4046* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"4225"* column

# %%
avocado_df["4225"].mean()
# Out:
# 295154.56835607433

# %%
avocado_df["4225"].min()
# Out:
# 0.0

# %%
avocado_df["4225"].max()
# Out:
# 20470572.61

# %%
avocado_df["4225"].median()
# Out:
# 29061.02

# %%
avocado_df["4225"].std()
# Out:
# 1204120.4011350493

# %%
avocado_df["4225"].var()
# Out:
# 1449905940429.6318

# %%
avocado_df["4225"].skew()
# Out:
# 8.942465607536276

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["4225"],color="navy")

plt.title("Histogram plot of 4225",y=1.02)
plt.xlabel("4225")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["4225"],kind="kde",color="lightgreen")

plt.title("Density plot of 4225",y=1.02)
plt.xlabel("4225")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["4225"].quantile(0.10),avocado_df["4225"].quantile(0.25),avocado_df["4225"].quantile(0.50),avocado_df["4225"].quantile(0.75),avocado_df["4225"].quantile(0.90)
# Out:
# (367.48400000000004, 3008.78, 29061.02, 150206.86, 500784.5520000004)

# %%
sns.boxplot(avocado_df["4225"],orient="h")

plt.title("Box plot for 4225",y=1.02)
plt.xlabel("4225")
plt.show()

# %%
sns.violinplot(avocado_df["4225"],orient="h",color="olive")

plt.title("Violin plot for 4225",y=1.02)
plt.xlabel("4225")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **4225** has an asymmetrical distribution i.e., it is skewed with a skewness value of 8.942
#
# * The Density curve of *4225* column is centered along mean 295154.568 with standard deviation of 1204120.401.
# * The range of the values is from 0 to 20470572.61.
# * Most of the values are in the range of 100 to 1000000.
# * 10% of times the total sales volume of Large Hass Avocados is 367.484 and below.
# * 25% of times the total sales volume of Large Hass Avocados is 3008.78 and below.
# * 50% of times the total sales volume of Large Hass Avocados is 29061.02 and below.
# * 75% of times the total sales volume of Large Hass Avocados is 150206.86 and below.
# * 90% of times the total sales volume of Large Hass Avocados is 500784.552 and below.
# * *4225* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"4770"* column

# %%
avocado_df["4770"].mean()
# Out:
# 22839.73599265713

# %%
avocado_df["4770"].min()
# Out:
# 0.0

# %%
avocado_df["4770"].max()
# Out:
# 2546439.11

# %%
avocado_df["4770"].median()
# Out:
# 184.99

# %%
avocado_df["4770"].std()
# Out:
# 107464.06843537689

# %%
avocado_df["4770"].var()
# Out:
# 11548526004.683367

# %%
avocado_df["4770"].skew()
# Out:
# 10.15939562715204

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["4770"],color="orange")

plt.title("Histogram plot of 4770",y=1.02)
plt.xlabel("4770")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["4770"],kind="kde",color="gold")

plt.title("Density plot of 4770",y=1.02)
plt.xlabel("4770")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["4770"].quantile(0.10),avocado_df["4770"].quantile(0.25),avocado_df["4770"].quantile(0.50),avocado_df["4770"].quantile(0.75),avocado_df["4770"].quantile(0.90)
# Out:
# (0.0, 0.0, 184.99, 6243.42, 31492.442000000035)

# %%
sns.boxplot(avocado_df["4770"],orient="h")

plt.title("Box plot for 4770",y=1.02)
plt.xlabel("4770")
plt.show()

# %%
sns.violinplot(avocado_df["4770"],orient="h",color="pink")

plt.title("Violin plot for 4770",y=1.02)
plt.xlabel("4770")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **4770** has an asymmetrical distribution i.e., it is skewed with a skewness value of 10.159
#
# * The Density curve of *4770* column is centered along mean 22839.735 with standard deviation of 107464.068.
# * The range of the values is from 0 to 2546439.11.
# * Most of the values are in the range of 0 to 100000.
# * 25% of times the total sales volume of Extra Large Hass Avocados is 0.
# * 50% of times the total sales volume of Extra Large Hass Avocados is 184.99 and below.
# * 75% of times the total sales volume of Extra Large Hass Avocados is 6243.42 and below.
# * 90% of times the total sales volume of Extra Large Hass Avocados is 31492.442 and below.
# * *4770* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"Total Bags"* column

# %%
avocado_df["Total Bags"].mean()
# Out:
# 239639.20205983886

# %%
avocado_df["Total Bags"].min()
# Out:
# 0.0

# %%
avocado_df["Total Bags"].max()
# Out:
# 19373134.37

# %%
avocado_df["Total Bags"].median()
# Out:
# 39743.83

# %%
avocado_df["Total Bags"].std()
# Out:
# 986242.3992164129

# %%
avocado_df["Total Bags"].var()
# Out:
# 972674070012.1465

# %%
avocado_df["Total Bags"].skew()
# Out:
# 9.756071670300289

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["Total Bags"],color="turquoise")

plt.title("Histogram plot of Total Bags",y=1.02)
plt.xlabel("Total Bags")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["Total Bags"],kind="kde",color="tomato")

plt.title("Density plot of Total Bags",y=1.02)
plt.xlabel("Total Bags")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["Total Bags"].quantile(0.10),avocado_df["Total Bags"].quantile(0.25),avocado_df["Total Bags"].quantile(0.50),avocado_df["Total Bags"].quantile(0.75),avocado_df["Total Bags"].quantile(0.90)
# Out:
# (1299.2080000000005, 5088.64, 39743.83, 110783.37, 442141.9280000002)

# %%
sns.boxplot(avocado_df["Total Bags"],orient="h")

plt.title("Box plot for Total Bags",y=1.02)
plt.xlabel("Total Bags")
plt.show()

# %%
sns.violinplot(avocado_df["Total Bags"],orient="h",color="teal")

plt.title("Violin plot for Total Bags",y=1.02)
plt.xlabel("Total Bags")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **Total Bags** has an asymmetrical distribution i.e., it is skewed with a skewness value of 9.756
#
# * The Density curve of *Total Bags* column is centered along mean 239639.202 with standard deviation of 986242.399.
# * The range of the values is from 0 to 19373134.37.
# * Most of the values are in the range of 0 to 450000.
# * 10% of times the total number of Bags sold is 1299.208 and below.
# * 25% of times the total number of Bags sold is 5088.64 and below.
# * 50% of times the total number of Bags sold is 39743.83 and below.
# * 75% of times the total number of Bags sold is 110783.37 and below.
# * 90% of times the total number of Bags sold is 442141.928 and below.
# * *Total Bags* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"Small Bags"* column

# %%
avocado_df["Small Bags"].mean()
# Out:
# 182194.68669570936

# %%
avocado_df["Small Bags"].min()
# Out:
# 0.0

# %%
avocado_df["Small Bags"].max()
# Out:
# 13384586.8

# %%
avocado_df["Small Bags"].median()
# Out:
# 26362.82

# %%
avocado_df["Small Bags"].std()
# Out:
# 746178.5149617859

# %%
avocado_df["Small Bags"].var()
# Out:
# 556782376190.576

# %%
avocado_df["Small Bags"].skew()
# Out:
# 9.540659981758614

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["Small Bags"],color="teal")

plt.title("Histogram plot of Small Bags",y=1.02)
plt.xlabel("Small Bags")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["Small Bags"],kind="kde",color="tan")

plt.title("Density plot of Small Bags",y=1.02)
plt.xlabel("Small Bags")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["Small Bags"].quantile(0.10),avocado_df["Small Bags"].quantile(0.25),avocado_df["Small Bags"].quantile(0.50),avocado_df["Small Bags"].quantile(0.75),avocado_df["Small Bags"].quantile(0.90)
# Out:
# (583.11, 2849.42, 26362.82, 83337.67, 354266.85200000025)

# %%
sns.boxplot(avocado_df["Small Bags"],orient="h")

plt.title("Box plot for Small Bags",y=1.02)
plt.xlabel("Small Bags")
plt.show()

# %%
sns.violinplot(avocado_df["Small Bags"],orient="h",color="violet")

plt.title("Violin plot for Small Bags",y=1.02)
plt.xlabel("Small Bags")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **Small Bags** has an asymmetrical distribution i.e., it is skewed with a skewness value of 9.541
#
# * The Density curve of *Small Bags* column is centered along mean 182194.686 with standard deviation of 746178.514.
# * The range of the values is from 0 to 13384586.8.
# * Most of the values are in the range of 0 to 350000.
# * 10% of times the total number of Small Bags sold is 583.11 and below.
# * 25% of times the total number of Small Bags sold is 2849.42 and below.
# * 50% of times the total number of Small Bags sold is 26362.82 and below.
# * 75% of times the total number of Small Bags sold is 83337.67 and below.
# * 90% of times the total number of Small Bags sold is 354266.852 and below.
# * *Small Bags* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"Large Bags"* column

# %%
avocado_df["Large Bags"].mean()
# Out:
# 54338.08814455587

# %%
avocado_df["Large Bags"].min()
# Out:
# 0.0

# %%
avocado_df["Large Bags"].max()
# Out:
# 5719096.61

# %%
avocado_df["Large Bags"].median()
# Out:
# 2647.71

# %%
avocado_df["Large Bags"].std()
# Out:
# 243965.9645474206

# %%
avocado_df["Large Bags"].var()
# Out:
# 59519391857.553276

# %%
avocado_df["Large Bags"].skew()
# Out:
# 9.796454598705258

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(avocado_df["Large Bags"],color="violet")

plt.title("Histogram plot of Large Bags",y=1.02)
plt.xlabel("Large Bags")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(avocado_df["Large Bags"],kind="kde",color="yellow")

plt.title("Density plot of Large Bags",y=1.02)
plt.xlabel("Large Bags")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["Large Bags"].quantile(0.10),avocado_df["Large Bags"].quantile(0.25),avocado_df["Large Bags"].quantile(0.50),avocado_df["Large Bags"].quantile(0.75),avocado_df["Large Bags"].quantile(0.90)
# Out:
# (0.0, 127.47, 2647.71, 22029.25, 94295.33800000006)

# %%
sns.boxplot(avocado_df["Large Bags"],orient="h")

plt.title("Box plot for Large Bags",y=1.02)
plt.xlabel("Large Bags")
plt.show()

# %%
sns.violinplot(avocado_df["Large Bags"],orient="h",color="lavender")

plt.title("Violin plot for Large Bags",y=1.02)
plt.xlabel("Large Bags")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **Large Bags** has an asymmetrical distribution i.e., it is skewed with a skewness value of 9.796
#
# * The Density curve of *Large Bags* column is centered along mean 54338.088 with standard deviation of 243965.964.
# * The range of the values is from 0 to 5719096.61.
# * Most of the values are in the range of 0 to 100000.
# * 10% of times the total number of Large Bags sold is 0.
# * 25% of times the total number of Large Bags sold is 127.47 and below.
# * 50% of times the total number of Large Bags sold is 2647.71 and below.
# * 75% of times the total number of Large Bags sold is 22029.25 and below.
# * 90% of times the total number of Large Bags sold is 94295.338 and below.
# * *Large Bags* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"XLarge Bags"* column

# %%
avocado_df["XLarge Bags"].mean()
# Out:
# 3106.426507205874

# %%
avocado_df["XLarge Bags"].min()
# Out:
# 0.0

# %%
avocado_df["XLarge Bags"].max()
# Out:
# 551693.65

# %%
avocado_df["XLarge Bags"].median()
# Out:
# 0.0

# %%
avocado_df["XLarge Bags"].std()
# Out:
# 17692.894651914357

# %%
avocado_df["XLarge Bags"].var()
# Out:
# 313038521.1637397

# %%
avocado_df["XLarge Bags"].skew()
# Out:
# 13.13975068600658

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.displot(avocado_df["XLarge Bags"],kind="kde",color="green")

plt.title("Density plot of XLarge Bags",y=1.02)
plt.xlabel("XLarge Bags")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
avocado_df["XLarge Bags"].quantile(0.10),avocado_df["XLarge Bags"].quantile(0.25),avocado_df["XLarge Bags"].quantile(0.50),avocado_df["XLarge Bags"].quantile(0.75),avocado_df["XLarge Bags"].quantile(0.90)
# Out:
# (0.0, 0.0, 0.0, 132.5, 3688.912)

# %%
sns.boxplot(avocado_df["XLarge Bags"],orient="h")

plt.title("Box plot for XLarge Bags",y=1.02)
plt.xlabel("XLarge Bags")
plt.show()

# %%
sns.violinplot(avocado_df["XLarge Bags"],orient="h",color="skyblue")

plt.title("Violin plot for XLarge Bags",y=1.02)
plt.xlabel("XLarge Bags")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **XLarge Bags** has an asymmetrical distribution i.e., it is skewed with a skewness value of 13.139
#
# * The Density curve of *XLarge Bags* column is centered along mean 3106.426 with standard deviation of 17692.894.
# * The range of the values is from 0 to 551693.65.
# * Most of the values are in the range of 0 to 4000.
# * 50% of times the total number of XLarge Bags sold is 0.
# * 75% of times the total number of XLarge Bags sold is 132.5 and below.
# * 90% of times the total number of XLarge Bags sold is 3688.912 and below.
# * *XLarge Bags* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"type"* column

# %%
avocado_df["type"].nunique()
# Out:
# 2

# %%
avocado_df["type"].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
avocado_df["type"].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
avocado_df["type"].value_counts(normalize=True)*100
# Out:
# conventional    50.00822
# organic         49.99178
# Name: type, dtype: float64

# %%
sns.countplot(x=avocado_df["type"])

plt.title("Count plot for type",y=1.02)
plt.xlabel("type")
plt.show()

# %%
sizes = [9126,9123]
plt.pie(sizes,labels=["conventional","organic"],autopct="%1.1f%%")

plt.title("Pie chart for type",y=1.02)
plt.legend()
plt.show()

# %% [markdown]
# #### Conclusion:
#
# It is observed that half of the avocados sold are conventional and the other half are organic.

# %% [markdown]
# ### Exploring *"region"* column

# %%
avocado_df["region"].nunique()
# Out:
# 54

# %%
avocado_df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %% [markdown]
# #### Conclusion:
#
# The different states of the USA where these avocados are sold are presented.

# %% [markdown]
# ### Plotting Heat Map

# %%
data = avocado_df[['AveragePrice','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','year']].corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data,cmap="vlag",annot=True,linewidth=.5)

plt.title("Heat Map",y=1.02)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * The correlation between the columns has been explored.

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Handling duplicate data

# %%
avocado_df.shape
# Out:
# (18249, 13)

# %%
avocado_df.drop_duplicates().shape
# Out:
# (18249, 13)

# %%
avocado_df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# #### Insights:
#
# It is identified that there are no duplicate rows in the data.

# %% [markdown]
# ### Checking null values

# %%
avocado_df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avocado_df.shape
# Out:
# (18249, 13)

# %% [markdown]
# #### Insights:
#
# It is identified that there are no null values in the data.

# %% [markdown]
# ### Handling outliers

# %% [markdown]
# #### *AveragePrice* column

# %%
avocado_df = avocado_df[avocado_df["AveragePrice"] <= 2.7]

# %%
avocado_df[avocado_df["AveragePrice"] > 2.7]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %% [markdown]
# #### *Total Volume* column

# %%
avocado_df = avocado_df[avocado_df["Total Volume"] <= 5000000]

# %% [markdown]
# #### *4046* column

# %%
avocado_df = avocado_df[avocado_df["4046"] <= 2000000]

# %% [markdown]
# #### *4225* column

# %%
avocado_df = avocado_df[avocado_df["4225"] <= 2000000]

# %% [markdown]
# #### *4770* column

# %%
avocado_df = avocado_df[avocado_df["4770"] <= 200000]

# %% [markdown]
# #### *Total Bags* column

# %%
avocado_df = avocado_df[avocado_df["Total Bags"] <= 2000000]

# %% [markdown]
# #### *Small Bags* column

# %%
avocado_df = avocado_df[avocado_df["Small Bags"] <= 1000000]

# %% [markdown]
# #### *Large Bags* column

# %%
avocado_df = avocado_df[avocado_df["Large Bags"] <= 300000]

# %% [markdown]
# #### *XLarge Bags* column

# %%
avocado_df = avocado_df[avocado_df["XLarge Bags"] <= 25000]

# %%
avocado_df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
avocado_df.reset_index(drop=True,inplace=True)
avocado_df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16721  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 16722  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 16723  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 16724  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 16725  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# #### Insights:
#
# The outliers have been handled in the respective columns by applying filtering condition.

# %% [markdown]
# ### Handling categorical values

# %%
first_condition = (avocado_df["region"].value_counts())/len(avocado_df)

avocado_df["region_encode"] = avocado_df["region"].apply(lambda x : first_condition[x])

# %%
avocado_df.drop(columns=["region"],inplace=True,axis=1)
avocado_df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region_encode
# 0       0.020208
# 1       0.020208
# 2       0.020208
# 3       0.020208
# 4       0.020208

# %%
avocado_df = pd.get_dummies(avocado_df,columns=["type"])
avocado_df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16721  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 16722  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 16723  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 16724  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 16725  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  year  region_encode  \
# ...

# %%
avocado_df.shape
# Out:
# (16726, 14)

# %% [markdown]
# #### Insights:
#
# The *region* column has been handled using **frequency encoding** and the *type* column has been handled using **one hot encoding**.

# %% [markdown]
# ### Handling numerical values

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
avocado_df[["AveragePrice","Total Volume","4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags"]] = scaler.fit_transform(avocado_df[["AveragePrice","Total Volume","4046","4225","4770","Total Bags","Small Bags","Large Bags","XLarge Bags"]])
avocado_df
# Out:
#              Date  AveragePrice  Total Volume      4046      4225      4770  \
# 0      2015-12-27     -0.246864     -0.443598 -0.425650 -0.219078 -0.325607
# 1      2015-12-20     -0.195421     -0.464874 -0.427574 -0.271012 -0.325082
# 2      2015-12-13     -1.275722     -0.320890 -0.426934  0.070298 -0.321351
# 3      2015-12-06     -0.889900     -0.410058 -0.425144 -0.126376 -0.324345
# 4      2015-11-29     -0.375471     -0.473596 -0.426155 -0.275247 -0.324180
# ...           ...           ...           ...       ...       ...       ...
# 16721  2018-02-04      0.524780     -0.550800 -0.420289 -0.499094 -0.328097
# 16722  2018-01-28      0.730552     -0.558044 -0.424828 -0.489029 -0.328097
# 16723  2018-01-21      1.142096     -0.558320 -0.424826 -0.494207 -0.290466
# 16724  2018-01-14      1.296424     -0.552777 -0.423045 -0.491412 -0.290514
# 16725  2018-01-07      0.499059     -0.549858 -0.415789 -0.494719 -0.316490
#
# ...

# %%
avocado_df["Date"] = pd.to_datetime(avocado_df["Date"])

# %%
avocado_df["Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 16726 entries, 0 to 16725
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 16726 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 130.8 KB

# %% [markdown]
# #### Insights:
#
# * The numerical columns have been handled using **StandardScaler** as the columns are skewed.
# * The datatype of *Date* column has been changed from object to datetime type.
